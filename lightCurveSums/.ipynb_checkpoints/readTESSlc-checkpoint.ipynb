# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import copy
import pickle

# %matplotlib inline

# %%
fp = open("~/tessSignalInjection/lcs/tesslcs_sector_1_104/tesslcs_tmag_2_3/tesslc_612256219.pkl ","rb")
data = pickle.load(fp)
fp.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e79b4b835621> in <module>
# ----> 1 fp = open("~/tessSignalInjection/lcs/tesslcs_sector_1_104/tesslcs_tmag_2_3/tesslc_612256219.pkl ","rb")
#       2 data = pickle.load(fp)
#       3 fp.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/tessSignalInjection/lcs/tesslcs_sector_1_104/tesslcs_tmag_2_3/tesslc_612256219.pkl '

# %%
times = data[6]
lc = data[8]

##cutTimes, cutLc = cutLightCurve(times, lc, 1545, 1555)

fig, ax = plt.subplots(1,1,figsize=(8,6))
ax.plot(cutTimes,cutLc,color="#1969ea",ls="-",lw=5)
plt.xlabel("Time",fontsize=14)
plt.ylabel("Flux",fontsize=14)
plt.title(r"TESS 612256219 Light Curve",fontsize=16)
plt.show()

# %%
maxlc = max(cutLc)
normLc = cutLc/maxlc

fig, ax = plt.subplots(1,1,figsize=(8,6))
ax.plot(cutTimes,normLc,color="#1969ea",ls="-",lw=5)
plt.xlabel("Time",fontsize=14)
plt.ylabel("Relative Flux",fontsize=14)
plt.title(r"TESS 612256219 Light Curve",fontsize=16)
plt.show()

# %%
def cutLightCurve(times, lc, t0, t1):
    newTimes = []
    newLc = []
    for i in range(len(times)):
        if times[i] > t0 and times[i] < t1:
            newTimes.append(times[i])
            newLc.append(lc[i])
            
    return newTimes,newLc
